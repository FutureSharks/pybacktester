# %%
import matplotlib.pyplot as plt
import pandas as pd
import pybacktester
import fx_data
from strategies import triple_ema_crossover as strategy

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20,10)

# %%
price_data = fx_data.get(provider='oanda', instrument='GBP_USD', year=2017, month=7, time_group='60min')
positions = strategy.apply(price_data.copy(), slow_ema=18, medium_ema=9, fast_ema=4)
position_graph = pybacktester.plot_positions(positions.copy())
# Out:
# 37 positions to plot...

# %%
plt.show()

# %%
stats, results, trades = pybacktester.run_backtest(
  positions.copy(),
  portfolio_value=10000,
  position_percentage=1,
  stop_pips=3,
  spread_pips=1.5
)

# %%
stats
# Out:
# {'drawdown_percent_95th': 22.13752140638462,
#  'drawdown_percent_max': 23.976894134541148,
#  'drawdown_percent_median': 14.126597429998546,
#  'end_portfolio_value': 142605.31998815172,
#  'loss_length_median': 6.5,
#  'pip_profit_factor': 5.8451688659126022,
#  'pips_per_loss_trade': -2.9777227075185047,
#  'pips_per_win_trade': 74.594108834177746,
#  'portfolio_lowest_value': 9700.0000000000327,
#  'profit_factor': 3.5697315560119032,
#  'return_percent': 1426.0531998815172,
#  'start_portfolio_value': 10000.0,
#  'total_pips': 432.82708061368913,
#  'trades': 37,
#  'trades_per_day': 1.2758620689655173,
#  'win_length_median': 28.0,
#  'win_loss_ratio': 0.23333333333333334,
#  'win_percent_median': 62.006430817609385}

# %%
pd.options.display.float_format = '{:20,.6f}'.format
trades
# Out:
#             enter_date          enter_price           exit_date  \
# 0  2017-07-02 22:00:00             1.302174 2017-07-02 23:00:00
# 1  2017-07-02 23:00:00             1.301425 2017-07-04 07:00:00
# 2  2017-07-04 08:00:00             1.293124 2017-07-04 23:00:00
# 3  2017-07-05 00:00:00             1.293753 2017-07-05 05:00:00
# 4  2017-07-05 05:00:00             1.292028 2017-07-05 15:00:00
# 5  2017-07-05 17:00:00             1.292340 2017-07-05 18:00:00
# 6  2017-07-05 19:00:00             1.293135 2017-07-07 05:00:00
# 7  2017-07-07 07:00:00             1.295634 2017-07-10 01:00:00
# 8  2017-07-10 06:00:00             1.290379 2017-07-10 07:00:00
# 9  2017-07-10 08:00:00             1.288393 2017-07-10 17:00:00
# 10 2017-07-10 22:00:00             1.287828 2017-07-11 07:00:00
# 11 2017-07-11 07:00:00             1.289250 2017-07-11 13:00:00
# 12 2017-07-11 13:00:00             1.286246 2017-07-12 10:00:00
# 13 2017-07-12 11:00:00             1.287010 2017-07-17 06:00:00
# 14 2017-07-17 10:00:00             1.306687 2017-07-18 01:00:00
# 15 2017-07-18 01:00:00             1.307518 2017-07-18 09:00:00
# 16 2017-07-18 09:00:00             1.303143 2017-07-18 18:00:00
# 17 2017-07-18 22:00:00             1.303691 2017-07-19 06:00:00
# 18 2017-07-19 07:00:00             1.303273 2017-07-19 10:00:00
# 0             True       False            -3.000000           100.000000
# 1            False        True            67.265110            97.000000
# 2             True       False            -3.000000           162.247157
# 3             True       False            -3.000000           157.379742
# 4             True       False            -3.000000           152.658350
# 5             True       False            -3.000000           148.078599
# 6             True       False            -3.000000           143.636241
# 7            False        True            62.006431           139.327154
# 8             True       False            -3.000000           225.718949
# 9            False       False            -2.428797           218.947381
# 10            True       False            -3.000000           213.629594
# 11            True       False            -3.000000           207.220707
# 12           False        True             5.697500           201.004085
# 13           False        True           213.560374           212.456293
# 14            True       False            -3.000000           666.178747
# 15            True       False            -3.000000           646.193384
# 16            True       False            -3.000000           626.807583
# 17           False       False            -2.902885           608.003355
# 18            True       False            -3.000000           590.353719
# 19            True       False            -3.000000           572.643108
# 20           False        True            54.263367           555.463814
# 21            True       False            -3.000000           856.877183
# 22            True       False            -3.000000           831.170867
# 23            True       False            -3.000000           806.235741
# 24            True       False            -3.000000           782.048669
# 25            True       False            -3.000000           758.587209
# 26            True       False            -3.000000           735.829593
# 27            True       False            -3.000000           713.754705
# 28            True       False            -3.000000           692.342064
# 29            True       False            -3.000000           671.571802
# 30           False        True            62.159167           651.424648
# 31            True       False            -3.000000         1,056.344780
# 32            True       False            -3.000000         1,024.654437
# 33            True       False            -3.000000           993.914804
# 34            True       False            -3.000000           964.097360
# 35            True       False            -3.000000           935.174439
# 36           False        True            57.206814           907.119206
#
#                  profit       profit_percent  portfolio_value_before  \
# 0           -300.000000            -3.000000           10,000.000000
# 1          6,524.715676            67.265110            9,700.000000
# 2           -486.741470            -3.000000           16,224.715676
# 3           -472.139226            -3.000000           15,737.974206
# 4           -457.975049            -3.000000           15,265.834980
# 5           -444.235798            -3.000000           14,807.859930
# 6           -430.908724            -3.000000           14,363.624132
# 7          8,639.179541            62.006431           13,932.715408
# 8           -677.156848            -3.000000           22,571.894949
# 9           -531.778657            -2.428797           21,894.738101
# 10          -640.888783            -3.000000           21,362.959444
# 11          -621.662120            -3.000000           20,722.070661
# 12         1,145.220777             5.697500           20,100.408541
# 13        45,372.245336           213.560374           21,245.629317
# 14        -1,998.536240            -3.000000           66,617.874653
# 15        -1,938.580152            -3.000000           64,619.338414
# 16        -1,880.422748            -3.000000           62,680.758261
# 17        -1,764.963586            -2.902885           60,800.335513
# 18        -1,771.061158            -3.000000           59,035.371928
# 19        -1,717.929323            -3.000000           57,264.310770
# 20        30,141.336822            54.263367           55,546.381447
# 21        -2,570.631548            -3.000000           85,687.718268
# 22        -2,493.512602            -3.000000           83,117.086720
# 23        -2,418.707224            -3.000000           80,623.574119
# 24        -2,346.146007            -3.000000           78,204.866895
# 25        -2,275.761627            -3.000000           75,858.720888
# 26        -2,207.488778            -3.000000           73,582.959261
# 27        -2,141.264115            -3.000000           71,375.470484
# 28        -2,077.026191            -3.000000           69,234.206369
# 29        -2,014.715405            -3.000000           67,157.180178
# 30        40,492.013249            62.159167           65,142.464773
# 31        -3,169.034341            -3.000000          105,634.478022
# 32        -3,073.963310            -3.000000          102,465.443681
# 33        -2,981.744411            -3.000000           99,391.480370
# 34        -2,892.292079            -3.000000           96,409.735959
# 35        -2,805.523316            -3.000000           93,517.443881
# 36        51,893.399424            57.206814           90,711.920564
#
#     portfolio_value_after
# 0            9,700.000000
# 1           16,224.715676
# 2           15,737.974206
# 3           15,265.834980
# 4           14,807.859930
# 5           14,363.624132
# 6           13,932.715408
# 7           22,571.894949
# 8           21,894.738101
# 9           21,362.959444
# 10          20,722.070661
# 11          20,100.408541
# 12          21,245.629317
# 13          66,617.874653
# 14          64,619.338414
# 15          62,680.758261
# 16          60,800.335513
# 17          59,035.371928
# 18          57,264.310770
# 19          55,546.381447
# 20          85,687.718268
# 21          83,117.086720
# 22          80,623.574119
# 23          78,204.866895
# 24          75,858.720888
# 25          73,582.959261
# 26          71,375.470484
# 27          69,234.206369
# 28          67,157.180178
# 29          65,142.464773
# 30         105,634.478022
# 31         102,465.443681
# 32          99,391.480370
# 33          96,409.735959
# 34          93,517.443881
# 35          90,711.920564
# 36         142,605.319988

# %%
results
# Out:
#         win_loss_ratio               trades       trades_per_day  \
# 0             0.233333            37.000000             1.275862
#
#             total_pips   pips_per_win_trade  pips_per_loss_trade  \
# 0           432.827081            74.594109            -2.977723
#
#      win_length_median   loss_length_median    pip_profit_factor  \
# 0            28.000000             6.500000             5.845169
#
#    start_portfolio_value  end_portfolio_value       return_percent  \
# 0          10,000.000000       142,605.319988         1,426.053200
#
#    portfolio_lowest_value   win_percent_median  drawdown_percent_max  \
# 0            9,700.000000            62.006431             23.976894
#
#    drawdown_percent_median  drawdown_percent_95th        profit_factor
# 0                14.126597              22.137521             3.569732

# %%
graph = pybacktester.plot_trades(positions.copy(), trades.copy())

# %%
plt.show()

# %%
monte_carlo_results = pybacktester.run_monte_carlo(
    trades.copy(),
    runs=1000,
    portfolio_value=10000,
    position_percentage=2
)
# Out:
# Running 1000 iterations of monte carlo...
# ....................................................................................................100 completed
# ....................................................................................................200 completed
# ....................................................................................................300 completed
# ....................................................................................................400 completed
# ....................................................................................................500 completed
# ....................................................................................................600 completed
# ....................................................................................................700 completed
# ....................................................................................................800 completed
# ....................................................................................................900 completed
# ....................................................................................................1000 completed
# .

# %%
monte_carlo_results
# Out:
# {'mc_median_drawdown_percent_95th': 44.26357833785812,
#  'mc_median_drawdown_percent_max': 48.754861717111154,
#  'mc_median_drawdown_percent_median': 21.243821273602144,
#  'mc_median_profit_factor': 2.698067029379851}
